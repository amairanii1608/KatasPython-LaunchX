# %%
asteroide=49
peligro=25
if asteroide > 25:
  print('¡PELIGRO! Asteroide se dirige a la Tierra a gran velocidad')
else:
  print('Fuera de PELIGRO')
# Out:
# ¡PELIGRO! Asteroide se dirige a la Tierra a gran velocidad

# %%
asteroide=19
peligro=20
if asteroide > 20:
  print('Si se puede ver el rayo de luz desde la Tierra')
else:
  print('No se puede ver el rayo')
# Out:
# No se puede ver el rayo

# %%
velAsteroide=50
tamAsteroide=40
if velAsteroide > 50 and tamAsteroide >25:
  print('¡PELIGRO! Asteroide se dirige a la Tierra a gran velocidad')
elif velAsteroide >=45:
  print('Si se puede ver el rayo de luz desde la Tierra')
elif velAsteroide <55:
  print('Fuera de PELIGRO')
# Out:
# Si se puede ver el rayo de luz desde la Tierra

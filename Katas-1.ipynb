# %%
from datetime import date
FechadeHoy=str(date.today())
print("Today's date is: ", FechadeHoy)
# Out:
# Today's date is:  2022-02-15

# %%
parsec=11
lightyears = 3.26156 * parsec
print("La conversion de: " + str(parsec) + " parsec, es " + str(lightyears) + " lightyears")
# Out:
# La conversion de: 11 parsec, es 35.877159999999996 lightyears
